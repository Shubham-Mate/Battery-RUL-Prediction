# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from constants import CALCEDatasetConstants
from preprocessing_functions import get_dates
import os

# %%
CALCEDatasetConstants.BATTERY_DATASET_PATHS
# Out:
# <CALCEDatasetConstants.BATTERY_DATASET_PATHS: [WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/CS2_3'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/CS2_5'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/CS2_6'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/CS2_7'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/CS2_8'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/CS2_9'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/CS2_21'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/CS2_24'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/CS2_25'), WindowsPath('C:/Users/shubham 
# ...

# %%
dates = []
for path in CALCEDatasetConstants.BATTERY_DATASET_PATHS.value:
    dates.append(get_dates(os.listdir(str(path))))
dates
# Out:
# [[datetime.date(2011, 9, 12),
#   datetime.date(2011, 9, 14),
#   datetime.date(2011, 9, 16),
#   datetime.date(2011, 9, 19),
#   datetime.date(2011, 9, 20),
#   datetime.date(2011, 9, 28),
#   datetime.date(2011, 10, 4),
#   datetime.date(2011, 10, 7),
#   datetime.date(2011, 10, 14),
#   datetime.date(2011, 10, 18),
#   datetime.date(2011, 10, 28),
#   datetime.date(2011, 11, 1),
#   datetime.date(2011, 11, 3),
#   datetime.date(2011, 11, 8),
#   datetime.date(2011, 11, 11),
#   datetime.date(2011, 11, 21),
#   datetime.date(2011, 11, 23),
#   datetime.date(2011, 11, 28),
#   datetime.date(2011, 12, 1),
#   datetime.date(2011, 12, 7),
#   datetime.date(2011, 12, 21),
#   datetime.date(2011, 12, 23),
#   datetime.date(2012, 1, 30),
#   datetime.date(2012, 2, 6),
#   datetime.date(2012, 2, 21),
#   datetime.date(2012, 3, 19),
#   datetime.date(2012, 3, 27),
#   datetime.date(2012, 4, 9),
#   datetime.date(2012, 4, 23),
#   datetime.date(2012, 5, 7),
#   datetime.date(2012, 7, 3),
# ...

# %%
filename = CALCEDatasetConstants.BATTERY_DATASET_PATHS.value[0] / \
(CALCEDatasetConstants.BATTERY_NAMES.value[0] + '_' + '_'.join([str(dates[0][0].month), str(dates[0][0].day), str(dates[0][0].year-2000)]) + '.xlsx')
filename
# Out:
# WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/CS2_3/CS2_3_9_12_11.xlsx')

# %%
df = pd.read_excel(filename, sheet_name='Channel_1-008')
df
# Out:
#        Data_Point   Test_Time(s)           Date_Time  Step_Time(s)  \
# 0               1      30.000032 2011-09-09 10:07:24     30.000033
# 1               2      30.000477 2011-09-09 10:07:24      0.000002
# 2               3      33.781753 2011-09-09 10:07:28      3.781279
# 3               4      43.797289 2011-09-09 10:07:38     13.796814
# 4               5      53.812566 2011-09-09 10:07:48     23.812091
# ...           ...            ...                 ...           ...
# 11561       11562  117746.647951 2011-09-10 18:49:26   1332.021586
# 11562       11563  117756.663409 2011-09-10 18:49:36   1342.037044
# 11563       11564  117766.678853 2011-09-10 18:49:46   1352.052488
# 11564       11565  117776.694303 2011-09-10 18:49:56   1362.067938
# 11565       11566  117782.194214 2011-09-10 18:50:01   1367.567848
#
#        Step_Index  Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0               1            1    0.000000    3.956663         0.000000e+00
# ...
