# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from constants import CALCEDatasetConstants
import preprocessing_functions
import os

# %%
CALCEDatasetConstants.BATTERY_DATASET_PATHS
# Out:
# <CALCEDatasetConstants.BATTERY_DATASET_PATHS: [WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/Raw/CS2_3'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/Raw/CS2_5'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/Raw/CS2_6'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/Raw/CS2_7'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/Raw/CS2_8'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/Raw/CS2_9'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/Raw/CS2_21'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/Raw/CS2_24'), WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/Raw/CS2_
# ...

# %%
dates = []
for path in CALCEDatasetConstants.BATTERY_DATASET_PATHS.value:
    dates.append(preprocessing_functions.get_dates(os.listdir(str(path))))
dates
# Out:
# [[datetime.date(2011, 9, 12),
#   datetime.date(2011, 9, 14),
#   datetime.date(2011, 9, 16),
#   datetime.date(2011, 9, 19),
#   datetime.date(2011, 9, 20),
#   datetime.date(2011, 9, 28),
#   datetime.date(2011, 10, 4),
#   datetime.date(2011, 10, 7),
#   datetime.date(2011, 10, 14),
#   datetime.date(2011, 10, 18),
#   datetime.date(2011, 10, 28),
#   datetime.date(2011, 11, 1),
#   datetime.date(2011, 11, 3),
#   datetime.date(2011, 11, 8),
#   datetime.date(2011, 11, 11),
#   datetime.date(2011, 11, 21),
#   datetime.date(2011, 11, 23),
#   datetime.date(2011, 11, 28),
#   datetime.date(2011, 12, 1),
#   datetime.date(2011, 12, 7),
#   datetime.date(2011, 12, 21),
#   datetime.date(2011, 12, 23),
#   datetime.date(2012, 1, 30),
#   datetime.date(2012, 2, 6),
#   datetime.date(2012, 2, 21),
#   datetime.date(2012, 3, 19),
#   datetime.date(2012, 3, 27),
#   datetime.date(2012, 4, 9),
#   datetime.date(2012, 4, 23),
#   datetime.date(2012, 5, 7),
#   datetime.date(2012, 7, 3),
# ...

# %%
filename = CALCEDatasetConstants.BATTERY_DATASET_PATHS.value[-1] / \
(CALCEDatasetConstants.BATTERY_NAMES.value[-1] + '_' + '_'.join([str(dates[-1][10].month), str(dates[-1][10].day), str(dates[-1][10].year-2000)]) + '.xlsx')
filename
# Out:
# WindowsPath('C:/Users/shubham mate/Desktop/Programming/Python/Battery RUL Project/data/CALCE/Raw/CS2_38/CS2_38_10_14_10.xlsx')

# %%
df = pd.read_excel(filename, sheet_name=1)
df
# Out:
#        Data_Point   Test_Time(s)           Date_Time  Step_Time(s)  \
# 0               1      30.000724 2010-10-06 09:37:04     30.000725
# 1               2      60.015163 2010-10-06 09:37:34     60.015164
# 2               3      90.030692 2010-10-06 09:38:04     90.030693
# 3               4     120.013938 2010-10-06 09:38:34    120.013938
# 4               5     150.029991 2010-10-06 09:39:04     30.015587
# ...           ...            ...                 ...           ...
# 16648       16649  575391.820486 2010-10-13 01:27:28   3231.407072
# 16649       16650  575398.054943 2010-10-13 01:27:34   3237.641529
# 16650       16651  575458.073276 2010-10-13 01:28:34     60.014791
# 16651       16652  575458.249800 2010-10-13 01:28:35      0.187470
# 16652       16653  575463.077907 2010-10-13 01:28:39      5.015578
#
#        Step_Index  Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0               1            1    0.000000    3.754661             0.000000
# ...

# %%
capacities = preprocessing_functions.process_battery_dataset(CALCEDatasetConstants.BATTERY_DATASET_PATHS.value[-1], CALCEDatasetConstants.BATTERY_NAMES.value[-1], dates[-1])

# %%
plt.plot(capacities['Cycle_Index'], capacities['Discharge_Capacity(Ah)'])
plt.plot(capacities['Cycle_Index'], capacities['Charge_Capacity(Ah)'])

plt.show()

# %%
print(capacities.to_string())
# Out:
#       Cycle_Index  Discharge_Capacity(Ah)  Charge_Capacity(Ah)                                                                                                        File_Path  File_Cycle_Index
# 0               1                1.139524             1.162412   C:\Users\shubham mate\Desktop\Programming\Python\Battery RUL Project\data\CALCE\Raw\CS2_38\CS2_38_8_17_10.xlsx                 1
# 1               2                1.138201             1.140774   C:\Users\shubham mate\Desktop\Programming\Python\Battery RUL Project\data\CALCE\Raw\CS2_38\CS2_38_8_18_10.xlsx                 1
# 2               3                1.137783             1.139106   C:\Users\shubham mate\Desktop\Programming\Python\Battery RUL Project\data\CALCE\Raw\CS2_38\CS2_38_8_19_10.xlsx                 1
# 3               4                1.136578             1.138544   C:\Users\shubham mate\Desktop\Programming\Python\Battery RUL Project\data\CALCE\Raw\CS2_38\CS2_38_8_30_10.xlsx                 1
# ...
